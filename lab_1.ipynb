# %%
import requests # to download html code
from bs4 import BeautifulSoup # to navigate through the html code
import pandas as pd
import numpy as np
import re

# %%
url = "https://www.billboard.com/charts/hot-100/"

# %%
def scrape_hot100(url_1):
    
    response = requests.get(url_1)
    soup = BeautifulSoup(response.text, 'html.parser')
    if response.status_code == 200:
        artist = []
        title = []
        for elem in soup.select("li.o-chart-results-list__item > span"):
            x = elem.get_text().strip()
            if re.match("\d{1,}|-|NEW|RE-\nENTRY", x):
                pass
            else:
                artist.append(x)
    
    
    
    
        for elem in soup.select("li.o-chart-results-list__item > h3"):
            t = (elem.get_text().strip())
            title.append(t)
    
        titles = pd.DataFrame({"Title" : title})

        artists = pd.DataFrame({"Artist" : artist})

        df = pd.concat([titles, artists], axis = 1)   
    
        return df
    else:
        return print("Page not found")

# %%
df = scrape_hot100(url)

# %%
df
# Out:
#                                      Title  \
# 0                            Break My Soul
# 1                                As It Was
# 2                          About Damn Time
# 3   Running Up That Hill (A Deal With God)
# 4                            Staying Alive
# ..                                     ...
# 95                                  Big 14
# 96                       Until I Found You
# 97                                Despecha
# 98                            Love Me More
# 99                                  7 Days
#
#                                   Artist
# 0                                Beyonce
# 1                           Harry Styles
# 2                                  Lizzo
# 3                              Kate Bush
# 4   DJ Khaled Featuring Drake & Lil Baby
# ..                                   ...
# 95   Trippie Redd, Moneybagg Yo & Offset
# 96                       Stephen Sanchez
# 97                               Rosalia
# ...
